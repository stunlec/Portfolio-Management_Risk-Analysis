# %% [markdown]
# # Solution 1

# %%
import pandas as pd
from math import pow,sqrt

# %%
def moment_dist(ser,deg):
    sum_val = ser.sum()
    mean = sum_val/len(ser)
    if deg==1:
        return mean
    
    sum_diff = 0
    for i in range(len(ser)):
        diff = ser[i]-mean
        sum_diff+=pow(diff,2)
        
    var = sum_diff/(len(ser)-1)
    SD = sqrt(var)
    
    if deg==2:
        return var
    
    sum_diff2 = 0
    if deg==3:
        for i in range(len(ser)):
            diff2 = ser[i]-mean
            num = diff2/SD
            sum_diff2 += pow(num,3)
    
        skew = sum_diff2/len(ser)
        return float(skew)
    
    if deg==4:
        for i in range(len(ser)):
            diff3 = ser[i]-mean
            num1 = diff3/SD
            sum_diff2 += pow(num1,4)
    
        kurt = sum_diff2/len(ser)
        return float(kurt)

# %% [markdown]
# # Solution 2

# %%
def Jarque_bera(ser):
    kurt = float(moment_dist(ser,4))
    skew = float(moment_dist(ser,3))
    n = float(len(ser))
    
    JB = (n/6)*((skew**2) + (1/4)*(kurt-3.0)**2)
    
    if JB>=0.0 and JB<=0.05:
        return True
    else:
        return False

# %% [markdown]
# # Solution 3

# %% [markdown]
# No, the real life stocks do not closely follow the normal distribution. For real life stocks to follow normal distribution its standard deviation has to be zero and kurtosis to be three. Jarque Bera(JB) test is used to see whether a distribution follows a normal distribution. If the JB is 0 or less than 0.05 we consider the distribution to be normal. We can test stocks from the csv whether they follow normal distribution or not ny using function in solution 2.

# %%
file=pd.read_csv(r"edhec-hedgefundindices.csv")
df=pd.DataFrame(file)
df
# Out:
#            date  Convertible Arbitrage  CTA Global  Distressed Securities  \
# 0    31/01/1997                   1.19        3.93                   1.78
# 1    28/02/1997                   1.23        2.98                   1.22
# 2    31/03/1997                   0.78       -0.21                  -0.12
# 3    30/04/1997                   0.86       -1.70                   0.30
# 4    31/05/1997                   1.56       -0.15                   2.33
# ..          ...                    ...         ...                    ...
# 258  31/07/2018                   0.21       -0.58                   0.93
# 259  31/08/2018                   0.24        1.66                   0.02
# 260  30/09/2018                   0.34       -0.54                   0.50
# 261  31/10/2018                  -0.73       -3.14                  -1.58
# 262  30/11/2018                  -0.68       -0.53                  -1.93
#
#      Emerging Markets  Equity Market Neutral  Event Driven  \
# 0                7.91                   1.89          2.13
# 1                5.25                   1.01          0.84
# 2               -1.20                   0.16         -0.23
# 3                1.19                   1.19         -0.05
# 4                3.15                   1.89          3.46
# ..                ...                    ...           ...
# 258              0.40                  -0.10          0.55
# 259             -2.77                   0.04          0.11
# 260             -1.10                  -0.16          0.32
# 261             -3.15                  -1.29         -2.57
# 262              1.20                  -2.11         -0.34
#
#      Fixed Income Arbitrage  Global Macro  Long/Short Equity  \
# 0                      1.91          5.73               2.81
# 1                      1.22          1.75              -0.06
# 2                      1.09         -1.19              -0.84
# 3                      1.30          1.72               0.84
# 4                      1.18          1.08               3.94
# ..                      ...           ...                ...
# 258                    0.22         -0.14               0.67
# 259                    0.17         -0.07               0.35
# 260                    0.36          0.06              -0.23
# 261                   -0.23         -0.96              -4.02
# 262                   -0.67         -0.87              -0.44
#
#      Merger Arbitrage  Relative Value  Short Selling  Funds Of Funds
# 0                1.50            1.80          -1.66            3.17
# 1                0.34            1.18           4.26            1.06
# 2                0.60            0.10           7.78           -0.77
# 3               -0.01            1.22          -1.29            0.09
# 4                1.97            1.73          -7.37            2.75
# ..                ...             ...            ...             ...
# 258             -0.21            0.45          -0.52            0.18
# 259              0.50           -0.02          -2.14            0.15
# 260              0.28            0.18           0.36           -0.22
# 261             -0.80           -1.09           2.37           -2.69
# 262              1.19           -0.63          -0.21           -0.71
#
# [263 rows x 14 columns]

# %%
import numpy as np
def hist_cvar(ser,t_period,alpha):
    ser = np.array(ser)
    ser = np.sort(ser)
    index = int((t_period*(alpha/100))-1)
    return ser[index]

df=pd.DataFrame(file)

print(hist_cvar(df['CTA Global'],263,5))
# Out:
# -3.33

# %%
column_list = list(df.columns.values)
column_list.remove("date")

for i in column_list:
    print("The stock",i,"follows Normal Distribution: ",Jarque_bera(df[i]))
# Out:
# The stock Convertible Arbitrage follows Normal Distribution:  False
# The stock CTA Global follows Normal Distribution:  False
# The stock Distressed Securities follows Normal Distribution:  False
# The stock Emerging Markets follows Normal Distribution:  False
# The stock Equity Market Neutral follows Normal Distribution:  False
# The stock Event Driven follows Normal Distribution:  False
# The stock Fixed Income Arbitrage follows Normal Distribution:  False
# The stock Global Macro follows Normal Distribution:  False
# The stock Long/Short Equity follows Normal Distribution:  False
# The stock Merger Arbitrage follows Normal Distribution:  False
# The stock Relative Value follows Normal Distribution:  False
# The stock Short Selling follows Normal Distribution:  False
# The stock Funds Of Funds follows Normal Distribution:  False

# %% [markdown]
# # Solution 4

# %%
skew = []
for i in column_list:
    m3 = moment_dist(df[i],3)
    skew.append(m3)
    print("Skew of stock",i,":",moment_dist(df[i],3))
    print("Kurtosis of stock",i,":",moment_dist(df[i],4))
    print("\n")
# Out:
# Skew of stock Convertible Arbitrage : -2.6245518362418747
# Kurtosis of stock Convertible Arbitrage : 23.10413046868022
#
#
# Skew of stock CTA Global : 0.17270891061343385
# Kurtosis of stock CTA Global : 2.930547088323327
#
#
# Skew of stock Distressed Securities : -1.2934298495867027
# Kurtosis of stock Distressed Securities : 7.8300975524744025
#
#
# Skew of stock Emerging Markets : -1.1604175475881044
# Kurtosis of stock Emerging Markets : 9.180573947137798
#
#
# Skew of stock Equity Market Neutral : -2.112330357266602
# Kurtosis of stock Equity Market Neutral : 17.087864609978542
#
#
# Skew of stock Event Driven : -1.4011242106238193
# Kurtosis of stock Event Driven : 7.9748353836061465
#
#
# Skew of stock Fixed Income Arbitrage : -3.9178683575631754
# Kurtosis of stock Fixed Income Arbitrage : 29.615693840647193
#
#
# Skew of stock Global Macro : 0.977321197894179
# Kurtosis of stock Global Macro : 5.698099494858525
#
#
# Skew of stock Long/Short Equity : -0.3880032631572966
# Kurtosis of stock Long/Short Equity : 4.489555760725092
#
#
# Skew of stock Merger Arbitrage : -1.3125615023375627
# Kurtosis of stock Merger Arbitrage : 8.67262024185954
#
#
# Skew of stock Relative Value : -1.805125207557475
# Kurtosis of stock Relative Value : 12.02920661996504
#
#
# Skew of stock Short Selling : 0.7635989258602068
# Kurtosis of stock Short Selling : 6.07133721860321
#
#
# Skew of stock Funds Of Funds : -0.3597216447188938
# Kurtosis of stock Funds Of Funds : 7.016489570837443

# %%
max_val=max(skew)
max_index=skew.index(max_val)

print("The stock with maximum skewness is:",column_list[max_index])
# Out:
# The stock with maximum skewness is: Global Macro
